# %%
from ipywidgets import interact

# %%
import numpy as np

# %%
def func(x, y, z):
  arr = np.array([x,y,z])
  print(np.min(arr))

# %%
func(2,3,1)
# Out:
# 1

# %%
i = interact(func, x=(0,10), y=(0,10), z=(0,10))
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10), IntSlider(value=5, description='y', max=10)…
